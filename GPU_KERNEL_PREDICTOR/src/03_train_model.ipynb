# %%
import joblib

# Assuming X_train is your training data and model is your trained model
X_train = ...  # Your feature matrix from the training data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Train your model (example using RandomForestRegressor)
model = RandomForestRegressor()
model.fit(X_train_scaled, y_train)

# Save the trained model, scaler, and feature columns
joblib.dump(model, 'data/processed/rf_model.pkl')  # Save model
joblib.dump(scaler, 'data/processed/scaler.pkl')  # Save scaler
joblib.dump(X_train.columns.tolist(), 'data/processed/feature_columns.pkl')  # Save feature columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 5
#       3 # Assuming X_train is your training data and model is your trained model
#       4 X_train = ...  # Your feature matrix from the training data
# ----> 5 scaler = StandardScaler()
#       6 X_train_scaled = scaler.fit_transform(X_train)
#       8 # Train your model (example using RandomForestRegressor)
#
# NameError: name 'StandardScaler' is not defined

# %%
train_columns = [
    'feature1', 'feature2', 'feature3',  # Replace with the actual feature names
    # Add all the columns that were used during training
]

# %%
import os
import joblib
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import StandardScaler

# Ensure the 'data/processed' directory exists
os.makedirs('data/processed', exist_ok=True)

# Assuming you have already loaded X and y data
# Train your model
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

model = RandomForestRegressor()
model.fit(X_scaled, y)

# Save the model and scaler
joblib.dump(model, 'data/processed/rf_model.pkl')
joblib.dump(scaler, 'data/processed/scaler.pkl')

# Save the feature columns if needed
feature_columns = X.columns  # Assuming X is a DataFrame
joblib.dump(feature_columns, 'data/processed/feature_columns.pkl')
# Out:
# c:\Users\saksh\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# ['data/processed/feature_columns.pkl']
